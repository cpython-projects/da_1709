# %% [markdown]
# <a href="https://colab.research.google.com/github/cpython-projects/da_1709/blob/main/lesson_24_hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Task 1. Кумулятивная выручка пользователя
# Как накапливалась сумма заказов у каждого пользователя по времени?

# %% [markdown]
# ## Task 2. Интервал между покупками
# Сколько дней прошло с предыдущего заказа пользователя?

# %% [markdown]
# ## Task 3. Предыдущая сумма покупки
# Какой была сумма предыдущего заказа пользователя?

# %% [markdown]
# ## Task 4. Максимальный заказ пользователя
# Какой самый крупный заказ был у каждого пользователя?

# %% [markdown]
# ## Task 5. Накопительное среднее чека
# Как меняется средний чек пользователя от заказа к заказу?

# %% [markdown]
# ## Task 6. Последний заказ пользователя
# Какова сумма последнего заказа пользователя?
