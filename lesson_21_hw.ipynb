# %% [markdown]
# <a href="https://colab.research.google.com/github/cpython-projects/da_1709/blob/main/lesson_21_hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Спроектировать базу данных для мобильного приложения по продаже товаров**
#
# ### 📁 **Сущности:**
#
# * Установки приложения (**app_sessions**)
# * Просмотры товаров (**product_views_log**)
# * Пользователи и устройства (**devices_users_map**)
# * Заказы (**orders_log**)
#
# ---
#
# ### 📁 **Поля:**
#
# #### **1. Таблица app_sessions**
#
# * **session_id**: уникальный идентификатор сессии
# * **device_code**: код устройства
# * **first_seen**: дата первого запуска приложения
# * **os_type**: платформа (Android или iOS)
# * **acquisition_channel**: канал привлечения (например, Facebook, Organic и т.д.)
# * **cpi_uah**: стоимость установки в гривнах
#
# ---
#
# #### **2. Таблица product_views_log — просмотры товаров**
#
# * **device_code**: код устройства
# * **view_date**: дата просмотра
# * **platform**: платформа
# * **view_count**: количество просмотров за день
#
# ---
#
# #### **3. Таблица devices_users_map**
#
# * **device_code**: код устройства
# * **user_uuid**: уникальный ID пользователя (присваивается после авторизации)
#
# 📌 **Обратите внимание:** не все пользователи проходят авторизацию
#
# ---
#
# #### **4. Таблица orders_log**
#
# * **user_uuid**: ID пользователя
# * **order_time**: дата и время заказа
# * **total_uah**: сумма покупки в гривнах
#
# ---
#
# ### 📁 **Связи:**
#
# * Одно устройство (**device_code**) может установить приложение только один раз
# * Одно устройство может многократно просматривать товары
# * Один пользователь может быть привязан к нескольким устройствам, но в системе идентифицируется по **user_uuid**
# * Один пользователь может сделать несколько заказов
# * Просмотры товаров происходят до авторизации, поэтому **device_code** связывает установки, просмотры и авторизованные покупки
#
# ---
#
# ### 📁 **Требования:**
#
# * Привести структуру базы данных к **3NF (третьей нормальной форме)**
# * Реализовать все сущности и связи в виде **SQL-кода для создания таблиц**
#
# ---
#
# ### 💾 **SQL для создания таблиц**
#
# ```sql
# CREATE TABLE app_sessions (
#
# );
#
# CREATE TABLE product_views_log (
#
# );
#
# CREATE TABLE devices_users_map (
#
# );
#
# CREATE TABLE orders_log (
#
# );
# ```
