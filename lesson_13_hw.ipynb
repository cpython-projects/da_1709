# %% [markdown]
# <a href="https://colab.research.google.com/github/cpython-projects/da_1709/blob/main/lesson_13_hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🏠 Разведка и диагностика качества данных
#
# **Датасет:** [House Sales in King County, USA (Kaggle)](https://www.kaggle.com/datasets/harlfoxem/housesalesprediction)
# Файл: `kc_house_data.csv`
#
# ---
#
# ### 🎯 Цель задания
#
# Провести **первичный анализ и диагностику данных**, выявить **проблемные признаки (столбцы)**, описать типичные **ошибки и возможные способы их исправления**.
#
# ---
#
# ### 🔹 Часть 1. Первичное знакомство
#
# 1. Загрузите датасет `kc_house_data.csv`.
# 2. Выведите общую информацию о данных (`.info()`).
# 3. Посмотрите первые 5 строк (`.head()`).
# 4. Узнайте количество строк и столбцов.
#
# **Вопросы:**
#
# * Сколько всего признаков и наблюдений?
# * Есть ли признаки, которые выглядят как числовые, но на самом деле строковые (или наоборот)?
#
# ---
#
# ### 🔹 Часть 2. Проверка на дубликаты
#
# 1. Найдите количество полных дубликатов строк.
# 2. Если дубликаты есть — покажите примеры.
# 3. Решите, стоит ли их удалять и почему.
#
# ---
#
# ### 🔹 Часть 3. Анализ пропусков
#
# 1. Посчитайте количество пропусков по каждому столбцу.
# 2. Постройте рейтинг столбцов по количеству пропусков (от большего к меньшему).
# 3. Найдите признаки, где пропусков **больше 20%**.
# 4. Прокомментируйте: какие из этих признаков можно удалить, а какие стоит попытаться восстановить?
#
# ---
#
# ### 🔹 Часть 4. Типы данных
#
# 1. Проверьте, соответствуют ли типы данных содержимому.
# 2. Найдите признаки, у которых:
#    * числовой тип, но категориальный смысл;
#    * строковый тип, но возможно содержат числа.
# 3. Предложите, где нужно изменить тип (`astype`, `pd.to_numeric`, `category` и т.д.).
#
# ---
#
# ### 🔹 Часть 5. Базовая статистика
#
# 1. Для числовых столбцов посчитайте:
#    * среднее (`mean`),
#    * медиану (`median`),
#    * минимум и максимум.
# 2. Найдите аномальные значения (например, нули там, где их быть не должно: площадь, количество комнат и т.д.; среднее и медиана значительно отличаются).
# 3. Приведите **2–3 примера подозрительных признаков**.
#
# ---
#
# ### 🔹 Часть 6. Интерпретация результатов
#
# Составьте короткий **отчёт (5–7 предложений)**:
#
# * Какие типы проблем вы обнаружили?
# * Сколько признаков потенциально требуют преобразования или очистки?
# * Какие три признака вы бы точно **удалили или исправили в первую очередь**, и почему?
