# %% [markdown]
# <a href="https://colab.research.google.com/github/cpython-projects/da_1709/blob/main/lesson_23_part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sqlalchemy import create_engine, text
import plotly.express as px

# %%
DB_USER = "prog_academy_da_yuq6_user"
DB_PASS = "nKLaf3orGpgat1GEpFbkuNVtxcNAGJp1"
DB_HOST = "dpg-d519e97pm1nc73briqk0-a.oregon-postgres.render.com"
DB_PORT = "5432"
DB_NAME = "prog_academy_da_yuq6"

# %%
engine = create_engine(f"postgresql+psycopg2://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}")

# %% [markdown]
# У нас есть пользователи, которые:
#
# * устанавливают приложение (`app_sessions`),
# * смотрят товары (`product_views_log`),
# * авторизуются (`devices_users_map`),
# * совершают покупки (`orders_log`).

# %% [markdown]
# # Работа с датами в SQL
# **Основные функции для работы с датой для анализа данных**

# %%
query = "SELECT * FROM app_sessions LIMIT 5;"
df = pd.read_sql(text(query), engine)
df
# Out:
#   session_id device_code  first_seen  os_type acquisition_channel  cpi_uah
# 0     S00000     DVC0000  2024-04-25  Android            Facebook    30.53
# 1     S00001     DVC0001  2024-01-15  Android            Referral    13.91
# 2     S00002     DVC0002  2024-01-18  Android            Facebook    31.80
# 3     S00003     DVC0003  2024-02-23      iOS            Referral    14.98
# 4     S00004     DVC0004  2024-04-24  Android          Google Ads    29.64

# %% [markdown]
# ## `DATE_TRUNC`
# **обрезает дату или время до заданной единицы измерения**, обнуляя менее значимые компоненты.

# %% [markdown]
# ### Общий синтаксис:
#
# ```sql
# DATE_TRUNC('единица_времени', timestamp)
# ```
#
# ---
#
# ### Для чего применяем:
#
# 1. **Группировка по времени**:
#    Чтобы сгруппировать данные по неделям, месяцам, дням и т.п.
# 2. **Округление до начала часа, дня и т.п.**
# 3. **Сравнение дат на уровне нужной точности** (например, все события за конкретный месяц).
#
# ---
#
# ### Поддерживаемые единицы:
#
# * `millennium`, `century`, `decade`, `year`, `quarter`, `month`
# * `week`, `day`, `hour`, `minute`, `second`

# %%
query = """
SELECT DATE_TRUNC('day', first_seen) FROM app_sessions
LIMIT 5;
"""
df = pd.read_sql(text(query), engine)
df
# Out:
#                  date_trunc
# 0 2024-04-25 00:00:00+00:00
# 1 2024-01-15 00:00:00+00:00
# 2 2024-01-18 00:00:00+00:00
# 3 2024-02-23 00:00:00+00:00
# 4 2024-04-24 00:00:00+00:00

# %%
query = """
SELECT DATE_TRUNC('month', first_seen) FROM app_sessions
LIMIT 5;
"""
df = pd.read_sql(text(query), engine)
df
# Out:
#                  date_trunc
# 0 2024-04-01 00:00:00+00:00
# 1 2024-01-01 00:00:00+00:00
# 2 2024-01-01 00:00:00+00:00
# 3 2024-02-01 00:00:00+00:00
# 4 2024-04-01 00:00:00+00:00

# %%
query = """
SELECT DATE_TRUNC('year', first_seen) FROM app_sessions
LIMIT 5;
"""
df = pd.read_sql(text(query), engine)
df
# Out:
#                  date_trunc
# 0 2024-01-01 00:00:00+00:00
# 1 2024-01-01 00:00:00+00:00
# 2 2024-01-01 00:00:00+00:00
# 3 2024-01-01 00:00:00+00:00
# 4 2024-01-01 00:00:00+00:00

# %% [markdown]
# ## `EXTRACT`
# **выделение отдельной компоненты даты или времени**, например: год, месяц, день, час и т.д.

# %% [markdown]
# ### Синтаксис:
#
# ```sql
# EXTRACT(единица_времени FROM дата_или_время)
# ```
#
# ---
#
# ### Используемые единицы:
#
# * `YEAR`
# * `MONTH`
# * `DAY`
# * `HOUR`
# * `MINUTE`
# * `SECOND`
# * `DOW` (day of week: 0 = Sunday, 6 = Saturday)
# * `DOY` (day of year)
# * `WEEK`
# * `QUARTER`
#
# ---
#
# ### Для чего применяем:
#
# 1. **Фильтрация по части даты**:
# 2. **Создание временных группировок**:
#
# ---
#
# ### Разница с `DATE_TRUNC`:
#
# |                | `EXTRACT`                     | `DATE_TRUNC`                                 |
# | -------------- | ----------------------------- | -------------------------------------------- |
# | Что делает     | Возвращает одно число         | Обнуляет менее значимые части даты           |
# | Тип результата | `numeric`                     | `timestamp`                                  |
# | Пример         | `EXTRACT(MONTH FROM d)` → `7` | `DATE_TRUNC('month', d)` → `'2025-07-01...'` |

# %%
query = """
SELECT EXTRACT(YEAR FROM first_seen) FROM app_sessions
LIMIT 5;
"""

df = pd.read_sql(text(query), engine)
df
# Out:
#    extract
# 0   2024.0
# 1   2024.0
# 2   2024.0
# 3   2024.0
# 4   2024.0

# %%
query = """
SELECT EXTRACT(MONTH FROM first_seen) FROM app_sessions
LIMIT 5;
"""

df = pd.read_sql(text(query), engine)
df
# Out:
#    extract
# 0      4.0
# 1      1.0
# 2      1.0
# 3      2.0
# 4      4.0

# %%
query = """
SELECT EXTRACT(DOW FROM first_seen) FROM app_sessions
LIMIT 5;
"""

df = pd.read_sql(text(query), engine)
df
# Out:
#    extract
# 0      4.0
# 1      1.0
# 2      4.0
# 3      5.0
# 4      3.0

# %% [markdown]
# ## `CURRENT_DATE`, `CURRENT_TIMESTAMP` и `NOW()`
# **текущее время и/или дата**

# %% [markdown]
# ### Особенности
#
# | Функция             | Что возвращает                 | Тип данных  | Пример результата            |
# | ------------------- | ------------------------------ | ----------- | ---------------------------- |
# | `CURRENT_DATE`      | Только текущую дату            | `DATE`      | `2025-07-14`                 |
# | `CURRENT_TIMESTAMP` | Текущие дата **и** время       | `TIMESTAMP` | `2025-07-14 11:25:32.123456` |
# | `NOW()`             | То же, что `CURRENT_TIMESTAMP` | `TIMESTAMP` | `2025-07-14 11:25:32.123456` |

# %%
query = """
SELECT CURRENT_DATE;
"""

with engine.connect() as connection:
    result = connection.execute(text(query))
    result = result.fetchone()
    print(result)
    print(type(result))
    print(result[0])
# Out:
# (datetime.date(2025, 7, 14),)
# <class 'sqlalchemy.engine.row.Row'>
# 2025-07-14

# %%
query = """
SELECT CURRENT_TIMESTAMP;
"""

with engine.connect() as connection:
    result = connection.execute(text(query))
    result = result.fetchone()
    print(result)
    print(type(result))
    print(result[0])
# Out:
# (datetime.datetime(2025, 7, 14, 16, 43, 6, 250581, tzinfo=datetime.timezone.utc),)
# <class 'sqlalchemy.engine.row.Row'>
# 2025-07-14 16:43:06.250581+00:00

# %%
query = """
SELECT NOW();
"""

with engine.connect() as connection:
    result = connection.execute(text(query))
    result = result.fetchone()
    print(result)
    print(type(result))
    print(result[0])
# Out:
# (datetime.datetime(2025, 7, 14, 16, 43, 52, 424084, tzinfo=datetime.timezone.utc),)
# <class 'sqlalchemy.engine.row.Row'>
# 2025-07-14 16:43:52.424084+00:00

# %% [markdown]
# ## `INTERVAL`
#  **Прибавление/вычитание временного промежутка**: дни, часы, месяцы, секунды и т.д.

# %% [markdown]
# ### 📌 Синтаксис:
#
# ```sql
# SELECT CURRENT_DATE + INTERVAL '7 days';
# ```
# ---
#
# ## Единицы измерения:
#
# * `second`, `minute`, `hour`
# * `day`, `week`, `month`, `year`
# * И даже комбинации:
#
# ```sql
# INTERVAL '2 days 3 hours 15 minutes'
# ```
# ---
#
# ## Особенности:
#
# * `INTERVAL` сам по себе не дата — это просто **временной отрезок**.
# * Может использоваться и с `DATE`, и с `TIMESTAMP`.
# * В некоторых СУБД, например MySQL, `INTERVAL` пишется иначе:
#
# ```sql
# -- MySQL стиль
# SELECT NOW() + INTERVAL 1 DAY;
# ```
# ---
#
# ### В Pandas аналог:
#
# ```python
# import pandas as pd
#
# pd.Timestamp.now() + pd.Timedelta(days=3, hours=2)
# ```

# %%
query = """
SELECT CURRENT_DATE + INTERVAL '7 day';
"""

with engine.connect() as connection:
    result = connection.execute(text(query))
    result = result.fetchone()
    print(result)
# Out:
# (datetime.datetime(2025, 7, 21, 0, 0),)

# %%
query = """
SELECT CURRENT_DATE + INTERVAL '7 month';
"""

with engine.connect() as connection:
    result = connection.execute(text(query))
    result = result.fetchone()
    print(result)
# Out:
# (datetime.datetime(2026, 2, 14, 0, 0),)

# %%
query = """
SELECT CURRENT_DATE + INTERVAL '2 years 1 month';
"""

with engine.connect() as connection:
    result = connection.execute(text(query))
    result = result.fetchone()
    print(result)
# Out:
# (datetime.datetime(2027, 8, 14, 0, 0),)

# %%
query = """
SELECT session_id, first_seen, first_seen - INTERVAL '1 day' AS minus_one_day FROM app_sessions;
"""

df = pd.read_sql(text(query), engine)
df
# Out:
#     session_id  first_seen minus_one_day
# 0       S00000  2024-04-25    2024-04-24
# 1       S00001  2024-01-15    2024-01-14
# 2       S00002  2024-01-18    2024-01-17
# 3       S00003  2024-02-23    2024-02-22
# 4       S00004  2024-04-24    2024-04-23
# ..         ...         ...           ...
# 495     S00495  2024-06-20    2024-06-19
# 496     S00496  2024-02-08    2024-02-07
# 497     S00497  2024-01-10    2024-01-09
# 498     S00498  2024-02-11    2024-02-10
# 499     S00499  2024-05-07    2024-05-06
#
# [500 rows x 3 columns]

# %% [markdown]
# ## Когда применяем работу с датами и временем

# %% [markdown]
# Анализ по дате и времени нужен в ситуациях, когда мы хотим:
#
# | Цель анализа                               | Когда применять                                               | Что нужно                         |
# | ------------------------------------------ | ------------------------------------------------------------- | --------------------------------- |
# | **1. Графики по дням / неделям / месяцам** | Отслеживать динамику показателей                              | Группировка по дате               |
# | **2. Сезонность**                          | Найти циклы в поведении (например, пятничные пики покупок)    | Группировка по дню недели, месяцу |
# | **3. Повторяемость покупок**               | Сколько дней проходит между покупками                         | Расчёт интервалов между датами    |
# | **4. RFM-анализ**                          | Сегментировать пользователей по их активности и ценности      | DATEDIFF, COUNT, SUM              |

# %% [markdown]
# ### 1. Графики **по дням, неделям, месяцам**
#
# **Зачем**: смотреть динамику продаж, посещений, заказов во времени.
#
# **Как**: используем `DATE_TRUNC`, `GROUP BY`, агрегаты.

# %%
# Сколько установок в день
query = """
SELECT first_seen, COUNT(*) AS installs
FROM app_sessions
GROUP BY first_seen
ORDER BY first_seen;
"""

df = pd.read_sql(text(query), engine)
df
# Out:
#      first_seen  installs
# 0    2024-01-01         3
# 1    2024-01-02         1
# 2    2024-01-03         3
# 3    2024-01-04         4
# 4    2024-01-05         3
# ..          ...       ...
# 169  2024-06-24         1
# 170  2024-06-25         2
# 171  2024-06-26         3
# 172  2024-06-27         1
# 173  2024-06-28         2
#
# [174 rows x 2 columns]

# %%
fig = px.line(df, x="first_seen", y="installs")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cfb9cabd-a097-4885-beb5-11089030cd8c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cfb9cabd-a097-4885-beb5-11089030cd8c")) {                    Plotly.newPlot(                        "cfb9cabd-a097-4885-beb5-11089030cd8c",                        [{"hovertemplate":"first_seen=%{x}\u003cbr\u003einstalls=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2024-01-01","2024-01-02","2024-01-03","2024-01-04","2024-01-05","2024-01-06","2024-01-07","2024-01-08","2024-01-10","2024-01-11","2024-01-12","2024-01-13","2024-01-14","2024-01-15","2024-01-16","2024-01-17","2024-01-18","2024-01-19","2024-01-20","2024-01-21","2024-01-22","2024-01-23","2024-01-24","2024-01-25","2024-01-26","2024-01-27","2024-01-28","2024-01-29","2024-01-30","2024-01-31","2024-02-01","2024-02-02","2024-02-03","2024-02-04","2024-02-06","2024-02-07","2024-02-08","2024-02-09","2024-02-10","2024-02-11","2024-02-12","2024-02-13","2024-02-14","2024-02-15","2024-02-16","2024-02-17","2024-02-18","2024-02-19","2024-02-20","2024-02-22","2024-02-23","2024-02-24","2024-02-25","2024-02-26","2024-02-27","2024-02-28","2024-02-29","2024-03-01","2024-03-02","2024-03-03","2024-03-04","2024-03-05","2024-03-06","2024-03-07","2024-03-09","2024-03-10","2024-03-11","2024-03-13","2024-03-14","2024-03-15","2024-03-16","2024-03-17","2024-03-18","2024-03-19","2024-03-20","2024-03-21","2024-03-22","2024-03-23","2024-03-24","2024-03-25","2024-03-26","2024-03-27","2024-03-28","2024-03-29","2024-03-30","2024-03-31","2024-04-01","2024-04-02","2024-04-03","2024-04-04","2024-04-05","2024-04-06","2024-04-07","2024-04-08","2024-04-09","2024-04-10","2024-04-11","2024-04-12","2024-04-13","2024-04-14","2024-04-15","2024-04-16","2024-04-17","2024-04-18","2024-04-19","2024-04-20","2024-04-21","2024-04-22","2024-04-23","2024-04-24","2024-04-25","2024-04-26","2024-04-27","2024-04-28","2024-04-29","2024-04-30","2024-05-01","2024-05-02","2024-05-03","2024-05-04","2024-05-05","2024-05-06","2024-05-07","2024-05-08","2024-05-09","2024-05-10","2024-05-11","2024-05-12","2024-05-13","2024-05-14","2024-05-15","2024-05-16","2024-05-17","2024-05-18","2024-05-19","2024-05-20","2024-05-21","2024-05-22","2024-05-23","2024-05-25","2024-05-26","2024-05-27","2024-05-28","2024-05-29","2024-05-30","2024-05-31","2024-06-01","2024-06-02","2024-06-03","2024-06-04","2024-06-05","2024-06-06","2024-06-07","2024-06-08","2024-06-09","2024-06-10","2024-06-11","2024-06-12","2024-06-13","2024-06-14","2024-06-15","2024-06-16","2024-06-17","2024-06-18","2024-06-19","2024-06-20","2024-06-21","2024-06-22","2024-06-23","2024-06-24","2024-06-25","2024-06-26","2024-06-27","2024-06-28"],"xaxis":"x","y":[3,1,3,4,3,3,4,4,4,2,3,5,5,2,2,3,4,1,3,3,5,5,1,1,3,3,3,4,3,1,3,4,2,1,1,3,2,6,2,3,2,1,2,1,3,2,2,6,2,3,6,2,1,4,1,2,4,1,4,2,6,2,2,4,3,2,7,4,3,1,1,2,3,2,3,1,3,1,2,4,5,1,4,4,1,3,4,2,3,3,4,1,2,5,3,6,2,1,2,7,3,4,2,6,2,3,4,3,3,6,1,3,6,2,2,2,1,3,1,5,1,1,2,3,1,7,2,1,5,1,4,5,1,3,3,4,2,2,1,5,1,3,5,2,3,6,1,2,1,3,1,1,2,5,4,2,3,2,2,2,1,1,5,2,6,4,4,10,3,1,2,3,1,2],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histo ...

# %%
# Сколько заказов по неделям
query = """
SELECT DATE_TRUNC('week', order_time) AS week, COUNT(*) AS orders
FROM orders_log
GROUP BY week
ORDER BY week;
"""

df = pd.read_sql(text(query), engine)
df
# Out:
#                         week  orders
# 0  2024-01-01 00:00:00+00:00     110
# 1  2024-01-08 00:00:00+00:00      99
# 2  2024-01-15 00:00:00+00:00     105
# 3  2024-01-22 00:00:00+00:00      95
# 4  2024-01-29 00:00:00+00:00     106
# 5  2024-02-05 00:00:00+00:00     111
# 6  2024-02-12 00:00:00+00:00     104
# 7  2024-02-19 00:00:00+00:00      92
# 8  2024-02-26 00:00:00+00:00     100
# 9  2024-03-04 00:00:00+00:00      98
# 10 2024-03-11 00:00:00+00:00      99
# 11 2024-03-18 00:00:00+00:00      97
# 12 2024-03-25 00:00:00+00:00     113
# 13 2024-04-01 00:00:00+00:00     105
# 14 2024-04-08 00:00:00+00:00      86
# 15 2024-04-15 00:00:00+00:00      96
# 16 2024-04-22 00:00:00+00:00      64
# 17 2024-04-29 00:00:00+00:00     112
# 18 2024-05-06 00:00:00+00:00      91
# 19 2024-05-13 00:00:00+00:00     109
# 20 2024-05-20 00:00:00+00:00     103
# 21 2024-05-27 00:00:00+00:00      89
# 22 2024-06-03 00:00:00+00:00     103
# 23 2024-06-10 00:00:00+00:00     109
# 24 2024-06-17 00:00:00+00:00      95
# 25 2024-06-24 00:00:00+00:00      68

# %%
fig = px.line(df, x="week", y="orders")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="56cccc07-1de9-4c3a-a201-2b23d659871e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56cccc07-1de9-4c3a-a201-2b23d659871e")) {                    Plotly.newPlot(                        "56cccc07-1de9-4c3a-a201-2b23d659871e",                        [{"hovertemplate":"week=%{x}\u003cbr\u003eorders=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2024-01-01T00:00:00+00:00","2024-01-08T00:00:00+00:00","2024-01-15T00:00:00+00:00","2024-01-22T00:00:00+00:00","2024-01-29T00:00:00+00:00","2024-02-05T00:00:00+00:00","2024-02-12T00:00:00+00:00","2024-02-19T00:00:00+00:00","2024-02-26T00:00:00+00:00","2024-03-04T00:00:00+00:00","2024-03-11T00:00:00+00:00","2024-03-18T00:00:00+00:00","2024-03-25T00:00:00+00:00","2024-04-01T00:00:00+00:00","2024-04-08T00:00:00+00:00","2024-04-15T00:00:00+00:00","2024-04-22T00:00:00+00:00","2024-04-29T00:00:00+00:00","2024-05-06T00:00:00+00:00","2024-05-13T00:00:00+00:00","2024-05-20T00:00:00+00:00","2024-05-27T00:00:00+00:00","2024-06-03T00:00:00+00:00","2024-06-10T00:00:00+00:00","2024-06-17T00:00:00+00:00","2024-06-24T00:00:00+00:00"],"xaxis":"x","y":[110,99,105,95,106,111,104,92,100,98,99,97,113,105,86,96,64,112,91,109,103,89,103,109,95,68],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555555555555 ...

# %%
# Сколько просмотров в месяц
query = """
SELECT DATE_TRUNC('month', view_date) AS month, COUNT(*) AS views
FROM product_views_log
GROUP BY month
ORDER BY month;
"""

df = pd.read_sql(text(query), engine)
df
# Out:
#                       month  views
# 0 2024-01-01 00:00:00+00:00    527
# 1 2024-02-01 00:00:00+00:00    536
# 2 2024-03-01 00:00:00+00:00    539
# 3 2024-04-01 00:00:00+00:00    534
# 4 2024-05-01 00:00:00+00:00    590
# 5 2024-06-01 00:00:00+00:00    507

# %%
fig = px.line(df, x="month", y="views")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3496dc8f-d5cf-45b7-95ed-ed986c0373fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3496dc8f-d5cf-45b7-95ed-ed986c0373fb")) {                    Plotly.newPlot(                        "3496dc8f-d5cf-45b7-95ed-ed986c0373fb",                        [{"hovertemplate":"month=%{x}\u003cbr\u003eviews=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2024-01-01T00:00:00+00:00","2024-02-01T00:00:00+00:00","2024-03-01T00:00:00+00:00","2024-04-01T00:00:00+00:00","2024-05-01T00:00:00+00:00","2024-06-01T00:00:00+00:00"],"xaxis":"x","y":[527,536,539,534,590,507],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":1 ...

# %% [markdown]
# ### 2. **Cезонность и циклы** (ежемесячная/еженедельная активность)
#
# **Зачем**: находить пики и спады по времени года, неделе, дню недели.
#
# **Как**: `EXTRACT(MONTH FROM date)`, `EXTRACT(DOW FROM date)`.

# %%
# Сколько заказов по дням недели
query = """
SELECT EXTRACT(DOW FROM order_time) AS day_of_week, COUNT(*) AS orders
FROM orders_log
GROUP BY day_of_week
ORDER BY day_of_week;
"""

df = pd.read_sql(text(query), engine)
df
# Out:
#    day_of_week  orders
# 0          0.0     332
# 1          1.0     393
# 2          2.0     347
# 3          3.0     381
# 4          4.0     363
# 5          5.0     365
# 6          6.0     378

# %% [markdown]
# ### 3. Повторяемость покупок
#
# **Зачем**: определить, как часто пользователи возвращаются и сколько времени проходит между покупками.
#
# **Как**: сравниваем `DATEDIFF` между заказами.

# %%
# Сколько дней между первой и последней покупкой
query = """
SELECT user_uuid, MAX(order_time) - MIN(order_time) AS days_between_orders, COUNT(*) AS orders
FROM orders_log
GROUP BY user_uuid
HAVING COUNT(*) > 1
ORDER BY days_between_orders DESC;
"""

df = pd.read_sql(text(query), engine)
df
# Out:
#     user_uuid  days_between_orders  orders
# 0     USR0268                  179      15
# 1     USR0125                  177      13
# 2     USR0269                  177      14
# 3     USR0272                  176      15
# 4     USR0042                  176      10
# ..        ...                  ...     ...
# 295   USR0191                   19       2
# 296   USR0096                   15       2
# 297   USR0130                   11       3
# 298   USR0132                    1       2
# 299   USR0140                    0       2
#
# [300 rows x 3 columns]

# %%
# Связь между количеством заказов и "жизненным циклом" пользователя
fig = px.scatter(df, x="orders", y="days_between_orders")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bb2b2b42-7064-4424-812e-18a819473924" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb2b2b42-7064-4424-812e-18a819473924")) {                    Plotly.newPlot(                        "bb2b2b42-7064-4424-812e-18a819473924",                        [{"hovertemplate":"orders=%{x}\u003cbr\u003edays_between_orders=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[15,13,14,15,10,13,10,13,7,15,13,14,4,8,14,10,9,11,15,13,15,14,11,9,15,3,14,13,13,5,14,7,14,13,13,12,14,9,13,8,8,12,5,9,15,15,12,9,15,14,4,12,15,13,10,10,6,13,9,14,13,12,2,5,4,13,5,15,11,11,12,9,8,7,14,11,13,13,5,9,12,13,10,11,7,15,10,13,12,15,7,11,12,5,9,7,13,15,13,10,11,6,13,12,9,10,14,10,13,7,10,5,12,12,15,8,13,14,14,14,14,11,15,7,12,10,7,12,15,7,10,9,13,15,4,3,12,15,4,8,3,8,10,6,8,12,9,7,14,7,11,2,9,10,10,9,13,8,15,5,15,3,9,8,14,11,9,6,9,6,5,3,9,7,7,12,5,12,13,8,12,6,7,10,6,9,4,8,5,2,9,9,11,7,12,4,7,14,7,5,8,6,11,10,5,2,8,7,9,12,5,9,2,13,3,8,10,7,10,7,7,7,2,7,10,4,11,6,13,4,11,5,2,7,6,8,6,3,10,4,5,6,9,8,3,6,9,5,3,5,6,5,6,5,4,2,8,9,3,7,7,5,6,2,3,7,3,3,4,2,2,3,4,7,4,3,3,3,5,3,2,3,2,7,2,4,4,5,2,3,2,4,2,3,2,2,2,3,2,2],"xaxis":"x","y":[179,177,177,176,176,175,175,174,174,173,173,173,173,173,172,172,172,171,171,171,171,171,171,171,171,170,170,170,170,170,169,169,169,169,169,169,169,169,168,168,168,168,168,167,167,166,166,166,166,166,165,165,165,164,164,164,164,164,164,164,164,163,162,162,162,162,162,161,161,161,161,160,160,160,160,160,159,159,159,159,159,159,159,158,158,158,158,157,157,157,157,157,157,157,157,156,156,156,156,155,155,154,154,154,154,154,154,153,152,152,152,152,152,151,151,151,151,151,151,150,150,149,149,149,149,148,148,148,147,147,146,146,146,146,146,146,145,145,145,145,145,144,144,144,143,143,143,143,143,143,143,143,142,142,142,141,141,141,141,140,140,140,140,140,139,139,139,138,138,138,138,137,137,137,137,136,135,134,134,134,133,133,133,133,133,133,132,132,132,131,130,128,128,127,127,127,127,127,127,126,126,125,125,125,124,124,123,123,123,122,122,122,121,121,121,121,121,121,121,120,120,119,119,118,118,117,116,115,114,114,113,113,112,112,111,111,110,110,110,110,109,107,105,105,104,104,104,103,101,100,99,97,96,96,94,94,92,90,90,89,89,88,85,85,85,82,81,81,80,79,79,75,72,71,71,67,64,62,60,54,53,53,48,47,46,44,43,42,42,36,30,29,29,27,21,19,15,11,1,0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"t ...

# %%
# сколько пользователей возвращаются через X дней?
fig = px.histogram(df, x="days_between_orders")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="716fd08f-5eaf-4485-9ae2-e1a9c6bc2ba6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("716fd08f-5eaf-4485-9ae2-e1a9c6bc2ba6")) {                    Plotly.newPlot(                        "716fd08f-5eaf-4485-9ae2-e1a9c6bc2ba6",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"days_between_orders=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[179,177,177,176,176,175,175,174,174,173,173,173,173,173,172,172,172,171,171,171,171,171,171,171,171,170,170,170,170,170,169,169,169,169,169,169,169,169,168,168,168,168,168,167,167,166,166,166,166,166,165,165,165,164,164,164,164,164,164,164,164,163,162,162,162,162,162,161,161,161,161,160,160,160,160,160,159,159,159,159,159,159,159,158,158,158,158,157,157,157,157,157,157,157,157,156,156,156,156,155,155,154,154,154,154,154,154,153,152,152,152,152,152,151,151,151,151,151,151,150,150,149,149,149,149,148,148,148,147,147,146,146,146,146,146,146,145,145,145,145,145,144,144,144,143,143,143,143,143,143,143,143,142,142,142,141,141,141,141,140,140,140,140,140,139,139,139,138,138,138,138,137,137,137,137,136,135,134,134,134,133,133,133,133,133,133,132,132,132,131,130,128,128,127,127,127,127,127,127,126,126,125,125,125,124,124,123,123,123,122,122,122,121,121,121,121,121,121,121,120,120,119,119,118,118,117,116,115,114,114,113,113,112,112,111,111,110,110,110,110,109,107,105,105,104,104,104,103,101,100,99,97,96,96,94,94,92,90,90,89,89,88,85,85,85,82,81,81,80,79,79,75,72,71,71,67,64,62,60,54,53,53,48,47,46,44,43,42,42,36,30,29,29,27,21,19,15,11,1,0],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8 ...

# %% [markdown]
# ### 4. Анализ RFM (Recency, Frequency, Monetary)
#
# **Зачем**: **метод сегментации клиентов** по их поведению в отношении заказов, который помогает понять ценность клиента и его лояльность.

# %% [markdown]
# #### Что означает каждая буква?
#
# | Параметр      | Что измеряет                    | Пример расчета                                            |
# | ------------- | ------------------------------- | --------------------------------------------------------- |
# | **Recency**   | Как давно был последний заказ   | Разница между сегодняшней датой и датой последнего заказа |
# | **Frequency** | Как часто клиент делает покупки | Количество заказов за период                              |
# | **Monetary**  | Сколько денег клиент принес     | Сумма всех заказов                                        |
#
# ---
#
# #### Для чего используется RFM?
#
# * **Сегментация**: найти VIP-клиентов, "спящих" клиентов, новых и т.д.
# * **Персонализация**: настроить email-маркетинг или push-уведомления
# * **Предсказание оттока**: кто может уйти

# %% [markdown]
# **Задача — оценить активность клиентов**:
# * Как давно был последний заказ (**Recency**),
# * Сколько всего заказов сделал клиент (**Frequency**),
# * На какую сумму клиент потратился (**Monetary**).

# %%
# Запрос для расчета RFM-показателей
query = """
SELECT
  user_uuid,
  CURRENT_DATE - MAX(order_time) AS recency,
  COUNT(*) AS frequency,
  SUM(total_uah) AS monetary
FROM orders_log
WHERE total_uah IS NOT NULL
GROUP BY user_uuid;
"""

rfm = pd.read_sql(text(query), engine)
rfm
# Out:
#     user_uuid  recency  frequency  monetary
# 0     USR0107      651          5   4947.18
# 1     USR0066      558         13  19064.47
# 2     USR0106      546         14  19179.84
# 3     USR0224      580          9  18292.62
# 4     USR0138      556         14  18920.32
# ..        ...      ...        ...       ...
# 295   USR0231      552         13  23953.07
# 296   USR0008      545         15  23048.32
# 297   USR0104      552         14  24700.33
# 298   USR0023      561         13  17250.25
# 299   USR0132      673          2   2353.09
#
# [300 rows x 4 columns]

# %%
# Recency: чем меньше дней — тем лучше (инверсия)
rfm["R"] = pd.qcut(rfm["recency"], 5, labels=[5,4,3,2,1])

# Frequency и Monetary: чем больше — тем лучше
rfm["F"] = pd.qcut(rfm["frequency"], 5, labels=[1,2,3,4,5])
rfm["M"] = pd.qcut(rfm["monetary"], 5, labels=[1,2,3,4,5])

# приводим к int
rfm[["R","F","M"]] = rfm[["R","F","M"]].astype(int)

# %%
rfm
# Out:
#     user_uuid  recency  frequency  monetary  R  F  M
# 0     USR0107      651          5   4947.18  1  2  1
# 1     USR0066      558         13  19064.47  3  4  4
# 2     USR0106      546         14  19179.84  5  5  4
# 3     USR0224      580          9  18292.62  2  3  4
# 4     USR0138      556         14  18920.32  3  5  4
# ..        ...      ...        ...       ... .. .. ..
# 295   USR0231      552         13  23953.07  4  4  5
# 296   USR0008      545         15  23048.32  5  5  5
# 297   USR0104      552         14  24700.33  4  5  5
# 298   USR0023      561         13  17250.25  3  4  4
# 299   USR0132      673          2   2353.09  1  1  1
#
# [300 rows x 7 columns]

# %% [markdown]
# **Recency (давность последней покупки)**
#
# ```python
# rfm["R"] = pd.qcut(rfm["recency"], 5, labels=[5, 4, 3, 2, 1]).astype(int)
# ```
#
# * `pd.qcut()` делит `recency` на **5 квантилей** (примерно равные по размеру группы).
# * `labels=[5, 4, 3, 2, 1]` — меньшее значение `recency` (то есть недавняя покупка) получает **лучший балл 5**.
# * То есть: покупал вчера → `recency = 1` → `R = 5`
#
# *Почему обратный порядок (5, 4, ..., 1)?*
#
# Потому что чем **меньше дней прошло с последней покупки**, тем **ценнее клиент**.
#
# ---
#
# **Frequency (частота покупок)**
#
# ```python
# rfm["F"] = pd.qcut(rfm["frequency"].rank(method="first"), 5, labels=[1, 2, 3, 4, 5]).astype(int)
# ```
#
# * `rank(method="first")` присваивает уникальные ранги (если значения одинаковые).
# * Затем `pd.qcut(..., 5)` разбивает их на 5 равных групп.
# * `labels=[1, 2, 3, 4, 5]` — чаще покупает → выше `frequency` → выше балл `F`
#
# ---
#
# **Monetary (сколько потратил)**
#
# ```python
# rfm["M"] = pd.qcut(rfm["monetary"], 5, labels=[1, 2, 3, 4, 5]).astype(int)
# ```
#
# * Всё просто: чем больше тратит, тем выше балл.
# * `qcut` делит пользователей по объёму трат на 5 групп от 1 (мало) до 5 (много).
#
# ---
#
# **Сборка итогового RFM-скора**
#
# ```python
# rfm["RFM_score"] = rfm["R"].astype(str) + rfm["F"].astype(str) + rfm["M"].astype(str)
# ```
#
# * Склеивает значения `R`, `F` и `M` в строку, например:
#   `R=5`, `F=3`, `M=4` → `RFM_score = "534"`
#
# ---
#
# **В результате:**
#
# | user\_id | R | F | M | RFM\_score |
# | -------- | - | - | - | ---------- |
# | 101      | 5 | 3 | 4 | "534"      |
# | 102      | 2 | 5 | 5 | "255"      |
#
# ---

# %%
def segment(row):

    # 1. Лучшие клиенты
    if row["R"] >= 4 and row["F"] >= 4 and row["M"] >= 4:
        return "VIP"

    # 2. Лояльные
    if row["R"] >= 3 and row["F"] >= 4:
        return "Loyal"

    # 3. Новые
    if row["F"] == 1 and row["R"] >= 4:
        return "New"

    # 4. Потенциально лояльные
    if row["R"] >= 4 and row["F"] in [2, 3]:
        return "Potential Loyalist"

    # 5. Под риском
    if row["R"] <= 2 and row["F"] <= 3 and row["M"] >= 3:
        return "At Risk"

    # 6. Потерянные VIP
    if row["R"] <= 2 and row["F"] >= 4 and row["M"] >= 4:
        return "Lost VIP"

    # 7. Спящие
    if row["R"] == 3 and row["F"] <= 2:
        return "Sleeping"

    # 8. Остальные
    return "Regular"

rfm["segment"] = rfm.apply(segment, axis=1)
rfm
# Out:
#     user_uuid  recency  frequency  monetary  R  F  M  segment
# 0     USR0107      651          5   4947.18  1  2  1  Regular
# 1     USR0066      558         13  19064.47  3  4  4    Loyal
# 2     USR0106      546         14  19179.84  5  5  4      VIP
# 3     USR0224      580          9  18292.62  2  3  4  At Risk
# 4     USR0138      556         14  18920.32  3  5  4    Loyal
# ..        ...      ...        ...       ... .. .. ..      ...
# 295   USR0231      552         13  23953.07  4  4  5      VIP
# 296   USR0008      545         15  23048.32  5  5  5      VIP
# 297   USR0104      552         14  24700.33  4  5  5      VIP
# 298   USR0023      561         13  17250.25  3  4  4    Loyal
# 299   USR0132      673          2   2353.09  1  1  1  Regular
#
# [300 rows x 8 columns]

# %%
color_map = {
    "VIP": "#D62728",               # красный
    "Loyal": "#FF7F0E",             # оранжевый
    "Potential Loyalist": "#1F77B4",# синий
    "New": "#9467BD",               # фиолетовый
    "Regular": "#7F7F7F",           # серый
    "At Risk": "#2CA02C",           # зелёный
    "Lost VIP": "#8C564B",          # коричневый
    "Sleeping": "#AEC7E8"            # светло-синий
}

fig = px.scatter(
    rfm,
    x="frequency",
    y="monetary",
    color="segment",
    color_discrete_map=color_map,
    title="RFM: Frequency vs Monetary",
    hover_data=["recency", "R", "F", "M"]
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c013e6a4-acd2-41c2-9c70-a591852103c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c013e6a4-acd2-41c2-9c70-a591852103c2")) {                    Plotly.newPlot(                        "c013e6a4-acd2-41c2-9c70-a591852103c2",                        [{"customdata":[[651,1,2,1],[663,1,1,1],[584,1,1,1],[566,2,2,2],[583,1,1,1],[609,1,1,2],[590,1,3,2],[568,2,2,2],[599,1,2,2],[566,2,1,1],[560,3,3,4],[593,1,2,2],[580,2,2,2],[586,1,1,1],[597,1,2,2],[586,1,1,1],[630,1,1,1],[558,3,3,4],[575,2,1,1],[614,1,1,2],[571,2,2,2],[633,1,1,1],[563,2,2,2],[557,3,3,3],[674,1,1,2],[565,2,1,2],[625,1,1,1],[604,1,1,1],[665,1,1,2],[566,2,3,2],[569,2,3,2],[674,1,1,1],[562,3,3,3],[572,2,1,1],[555,3,3,4],[579,2,2,2],[702,1,1,1],[621,1,1,1],[592,1,1,2],[616,1,1,1],[647,1,1,1],[575,2,1,1],[634,1,1,1],[570,2,1,1],[585,1,2,2],[565,2,2,2],[569,2,2,2],[580,2,2,2],[583,1,1,1],[600,1,2,2],[582,1,1,1],[584,1,1,1],[575,2,1,1],[639,1,1,1],[606,1,2,2],[614,1,1,1],[573,2,2,2],[567,2,2,1],[565,2,2,2],[557,3,3,4],[592,1,2,2],[555,3,3,3],[588,1,3,2],[615,1,1,1],[619,1,1,1],[636,1,1,2],[596,1,1,1],[605,1,2,1],[598,1,1,1],[560,3,3,3],[653,1,1,1],[567,2,1,1],[555,3,3,4],[563,2,1,1],[597,1,2,2],[622,1,1,1],[594,1,1,1],[570,2,2,2],[673,1,1,1]],"hovertemplate":"segment=Regular\u003cbr\u003efrequency=%{x}\u003cbr\u003emonetary=%{y}\u003cbr\u003erecency=%{customdata[0]}\u003cbr\u003eR=%{customdata[1]}\u003cbr\u003eF=%{customdata[2]}\u003cbr\u003eM=%{customdata[3]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Regular","marker":{"color":"#7F7F7F","symbol":"circle"},"mode":"markers","name":"Regular","orientation":"v","showlegend":true,"x":[5,2,3,7,3,4,9,6,5,3,10,5,5,2,7,2,3,10,3,3,7,3,5,9,4,4,2,3,4,9,8,2,8,2,10,7,2,3,4,3,2,3,2,2,7,6,5,7,2,6,2,2,3,4,5,4,5,5,7,8,5,9,8,2,3,3,2,6,3,10,3,2,9,4,5,2,2,5,2],"xaxis":"x","y":[4947.18,4384.64,4883.05,9876.69,5802.83,8678.44,9750.1,10739.73,9524.93,5601.12,15892.72,6455.66,9124.79,4687.96,9241.81,791.53,4567.81,18072.41,4429.46,7311.35,8633.84,1329.25,8076.62,14677.78,7439.6,6792.48,2118.17,3608.77,7702.39,10555.76,7672.23,2269.79,13350.59,2512.82,15195.52,10065.17,2936.3,3249.89,6796.7,2972.95,3924.05,6010.47,4377.39,3163.66,10437.62,10830.83,11058.05,9320.1,4508.05,9677.69,3515.44,4725.29,4606.16,5423.69,8066.1,4907.95,9991.12,5163.02,9516.05,15220.77,7711.39,11671.71,10954.72,3688.61,3678.14,7027.52,2419.75,6057.01,5778.66,14681.37,2040.44,4676.48,19006.65,4872.08,9077.62,2681.51,4171.09,7331.13,2353.09],"yaxis":"y","type":"scatter"},{"customdata":[[558,3,4,4],[556,3,5,4],[561,3,5,5],[554,3,4,3],[556,3,4,5],[559,3,5,5],[561,3,5,5],[544,5,4,3],[559,3,4,5],[556,3,4,5],[560,3,5,4],[549,4,4,3],[560,3,4,4],[544,5,4,3],[561,3,4,4],[554,3,4,4],[562,3,4,3],[556,3,5,5],[556,3,4,3],[556,3,5,5],[557,3,4,3],[560,3,4,4],[557,3,5,5],[562,3,5,5],[561,3,4,4]],"hovertemplate":"segment=Loyal\u003cbr\u003efrequency=%{x}\u003cbr\u003emonetary=%{y}\u003cbr\u003erecency=%{customdata[0]}\u003cbr\u003eR=%{customdata[1]}\u003cbr\u003eF=%{customdata[2]}\u003cbr\u003eM=%{customdata[3]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Loyal","marker":{"color":"#FF7F0E","symbol":"circle"},"mode":"markers","name":"Loyal","orientation":"v","showlegend":true,"x":[13,14,14,11,11,15,15,13,12,13,15,12,11,13,13,11,12,15,13,14,11,11,14,15,13],"xaxis":"x","y":[19064.47,18920.32,22801.25,13666.29,21402.53,25493.8,29386.41,11860.71,20794.26,21780.1,19600.13,14427.13,18540.04,14732.05,15667.52,17931.22,14268.24,22635.47,14190.67,20594.55,13951.77,16625.95,21372.39,25904.22,17250.25],"yaxis":"y","type":"scatter"},{"customdata":[[546,5,5,4],[550,4,5,5],[542,5,5,4],[543,5,5,5],[543,5,4,4],[542,5,5,5],[544,5,5,5],[547,5,4,5],[551,4,5,5],[546,5,4,5],[545,5,4,5 ...

# %%
seg_dist = rfm["segment"].value_counts().reset_index()
seg_dist.columns = ["segment", "count"]

fig = px.bar(
    seg_dist,
    x="segment",
    y="count",
    title="Customer Distribution by RFM Segment",
    text="count"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d269a0fe-3ae9-4a66-9ec9-356aef4c5e45" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d269a0fe-3ae9-4a66-9ec9-356aef4c5e45")) {                    Plotly.newPlot(                        "d269a0fe-3ae9-4a66-9ec9-356aef4c5e45",                        [{"alignmentgroup":"True","hovertemplate":"segment=%{x}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[79.0,60.0,49.0,30.0,26.0,25.0,19.0,12.0],"textposition":"auto","x":["Regular","VIP","Potential Loyalist","At Risk","Sleeping","Loyal","Lost VIP","New"],"xaxis":"x","y":[79,60,49,30,26,25,19,12],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"sol ...
